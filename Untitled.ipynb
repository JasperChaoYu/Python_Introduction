# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Python Download
#
# - https://www.python.org/downloads/

# %% [markdown]
# # Development Environment
#
# - cmd
#
#
# - Spyder
#     1. https://pythonhosted.org/spyder/overview.html
#
#
# - Jupyter IPython Notebook
#     1. http://jupyter.org
#     2. https://ipython.org

# %% [markdown]
# # Python Standard Modules
#
#  - https://docs.python.org/2/library/index.html

# %%
help("modules")
# Out:
# Please wait a moment while I gather a list of all available modules...
#
# Audio_mac           alabaster           hmac                requests
# BaseHTTPServer      antigravity         hotshot             requests_file
# Bastion             anydbm              htmlentitydefs      requests_ftp
# CGIHTTPServer       applesingle         htmllib             resource
# Canvas              appletrawmain       httplib             rexec
# Carbon              appletrunner        ic                  rfc822
# CodeWarrior         appnope             icglue              rlcompleter
# ColorPicker         argparse            icopen              rmagic
# ConfigParser        argvemulator        idlelib             robotparser
# Cookie              array               idna                rope
# Dialog              ast                 ihooks              runpy
# DocXMLRPCServer     astroid             imagesize           sched
# EasyDialogs         asynchat            imaplib             scipy
# Explorer            asyncore            imghdr              seaborn
# FileDialog          atexit              imp                 select
# Finder              audiodev            importlib           sets
# FixTk               audioop             imputil             setuptools
# FrameWork           autoGIL             inspect             sgmllib
# HTMLParser          autoreload          io                  sha
# IN                  babel               ipykernel           shelve
# IPython             backports           ipython_genutils    shlex
# MacOS               backports_abc       ipywidgets          shutil
# MimeWriter          base64              isort               shutil_backports
# MiniAEFrame         bdb                 itertools           signal
# Nav                 bgenlocations       jedi                simplegeneric
# Netscape            binascii            jinja2              simplejson
# OSATerminology      binhex              json                singledispatch
# PixMapWrapper       bisect              jsonschema          singledispatch_helpers
# Queue               black               jupyter             site
# ScrolledText        black_scholes       jupyter_client      six
# SimpleDialog        black_scholes_merton jupyter_console     sklearn
# SimpleHTTPServer    bogus_honeypot      jupyter_core        smtpd
# SimpleXMLRPCServer  brain_builtin_inference keyword             smtplib
# SocketServer        brain_dateutil      lazy_object_proxy   sndhdr
# StdSuites           brain_gi            lib2to3             snowballstemmer
# StringIO            brain_mechanize     linecache           socket
# SystemEvents        brain_nose          locale              sphinx
# Terminal            brain_numpy         logging             sphinxify
# Tix                 brain_pytest        macerrors           spyder
# Tkconstants         brain_qt            macostools          spyder_breakpoints
# Tkdnd               brain_six           macpath             spyder_io_dcm
# Tkinter             brain_ssl           macresource         spyder_io_hdf5
# UserDict            brain_stdlib        macurl2path         spyder_profiler
# UserList            bs4                 mailbox             spyder_pylint
# UserString          bsddb               mailcap             sqlite3
# _AE                 buildtools          markupbase          sre
# _AH                 bundlebuilder       markupsafe          sre_compile
# _App                bz2                 marshal             sre_constants
# _CF                 cPickle             math                sre_parse
# _CG                 cProfile            matplotlib          ssl
# _CarbonEvt          cStringIO           mccabe              stat
# _Cm                 calendar            md5                 statvfs
# _Ctl                certifi             mhlib               storemagic
# _Dlg                cfmfile             mimetools           string
# _Drag               cgi                 mimetypes           stringold
# _Evt                cgitb               mimify              stringprep
# _File               chardet             mistune             strop
# _Fm                 chunk               mmap                struct
# _Folder             cmath               modulefinder        subprocess
# _Help               cmd                 monthdelta          sunau
# _IBCarbon           code                multifile           sunaudio
# _Icn                codecs              multiprocessing     symbol
# _LWPCookieJar       codeop              mutex               sympyprinting
# _Launch             collections         nbconvert           symtable
# _List               colorlover          nbformat            sys
# _Menu               colorsys            netrc               sysconfig
# _Mlte               commands            new                 syslog
# _MozillaCookieJar   compileall          nis                 tabnanny
# _OSA                compiler            nntplib             tarfile
# _Qd                 conf                notebook            telnetlib
# _Qdoffs             configparser        ntpath              tempfile
# _Qt                 contextlib          nturl2path          terminado
# _Res                cookielib           numbers             terminalcommand
# _Scrap              copy                numpy               termios
# _Snd                copy_reg            opcode              test
# _TE                 crypt               operator            tests
# _Win                csv                 optparse            textwrap
# __builtin__         ctypes              os                  this
# __future__          cufflinks           os2emxpath          thread
# _abcoll             curses              pandas              threading
# _ast                cvxopt              pandas_datareader   time
# _bisect             cycler              parser              timeit
# _bsddb              cythonmagic         pathlib2            tkColorChooser
# _builtinSuites      datetime            pdb                 tkCommonDialog
# _codecs             dateutil            pep8                tkFileDialog
# _codecs_cn          dbhash              pexpect             tkFont
# _codecs_hk          dbm                 pickle              tkMessageBox
# _codecs_iso2022     decimal             pickleshare         tkSimpleDialog
# _codecs_jp          decorator           pickletools         toaiff
# _codecs_kr          difflib             pimp                token
# _codecs_tw          dircache            pip                 tokenize
# _collections        dis                 pipes               tornado
# _csv                distutils           pkg_resources       trace
# _ctypes             doctest             pkgutil             traceback
# _ctypes_test        docutils            platform            traitlets
# _curses             dumbdbm             plistlib            ttk
# _curses_panel       dummy_thread        plotly              tty
# _elementtree        dummy_threading     popen2              turtle
# _functools          easy_install        poplib              types
# _hashlib            email               posix               unicodedata
# _heapq              encodings           posixfile           unittest
# _hotshot            ensurepip           posixpath           urllib
# _io                 entrypoints         pprint              urllib2
# _json               enum                profile             urllib3
# _locale             errno               prompt_toolkit      urlparse
# _lsprof             exceptions          pstats              user
# _multibytecodec     fcntl               psutil              uu
# _multiprocessing    filecmp             pty                 uuid
# _osx_support        fileinput           ptyprocess          videoreader
# _pyio               findertools         pwd                 vollib
# _random             fnmatch             py_compile          warnings
# _scproxy            formatter           py_lets_be_rational wave
# _socket             fpformat            py_vollib           wcwidth
# _sqlite3            fractions           pyclbr              weakref
# _sre                ftplib              pydoc               webbrowser
# _ssl                functools           pydoc_data          whichdb
# _strptime           functools32         pyexpat             widgetsnbextension
# _struct             future_builtins     pyflakes            wrapt
# _symtable           gc                  pygments            wsgiref
# _sysconfigdata      genericpath         pylab               xdrlib
# _testcapi           gensuitemodule      pylint              xlrd
# _threading_local    gestalt             pyparsing           xml
# _tkinter            getopt              pytz                xmllib
# _warnings           getpass             qtawesome           xmlrpclib
# _weakref            gettext             qtconsole           xxsubtype
# _weakrefset         glob                qtpy                zipfile
# abc                 grp                 quopri              zipimport
# aepack              gzip                random              zlib
# aetools             hashlib             re                  zmq
# aetypes             heapq               readline
# aifc                helper              repr
#
# Enter any module name to get more help.  Or, type "modules spam" to search
# for modules whose descriptions contain the word "spam".

# %% [markdown]
# # Data Structures
#
# 1. List
#
# https://github.com/JasperChaoYu/Python_Introduction/blob/master/Data%20Structure/Data%20Structure%20-%20List.ipynb
#
# 2. Tuple
#
# https://github.com/JasperChaoYu/Python_Introduction/blob/master/Data%20Structure/Data%20Structure%20-%20Tuple.ipynb
#
# 3. Datetime
#
# https://github.com/JasperChaoYu/Python_Introduction/blob/master/Data%20Structure/Data%20Structure%20-%20Datetime.ipynb
#
# 4. DataFrame
#
# https://github.com/JasperChaoYu/Python_Introduction/blob/master/Data%20Structure/Data%20Structure%20-%20Dataframe.ipynb
#
# 5. Dictionary
#
# https://github.com/JasperChaoYu/Python_Introduction/blob/master/Data%20Structure/Data%20Structure%20-%20Dictionary.ipynb

# %% [markdown]
# # Coding Rules
#
# - 縮排
#
#
# - Loops and Conditions
#
# https://github.com/JasperChaoYu/Python_Introduction/blob/master/Loop%20and%20Conditions/Python%20Loops%20and%20Conditions.ipynb
#
# - Functions
#
# https://github.com/JasperChaoYu/Python_Introduction/blob/master/Functions/Python%20Functions.ipynb

# %% [markdown]
# # Brief Python Modules Introductions
#
#  - install modules
#
#  https://docs.python.org/2/installing/index.html
#
#  - import modules
#
#  https://github.com/JasperChaoYu/Python_Introduction/blob/master/Packages/Python%20Packages_github.ipynb
#
# *
#
# numpy
#
# http://cs231n.github.io/python-numpy-tutorial/
#
# matplotlib
#
# https://pythonprogramming.net/plotting-monte-carlo-matplotlib/

# %% [markdown]
# # Financial Data Processing
#
# - pandas_datareader
#
#     1. download data from yahoo or google
#
#     2. documnets : https://pandas-datareader.readthedocs.io/en/latest/

# %%
import datetime
import pandas_datareader

start = datetime.datetime(2017, 9, 1)
end = datetime.datetime.today()

# %%
pandas_datareader.DataReader("AAPL", "yahoo", start, end)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-08-31  163.639999  164.520004  163.479996  164.000000  164.000000
# 2017-09-01  164.800003  164.940002  163.630005  164.050003  164.050003
# 2017-09-05  163.750000  164.250000  160.559998  162.080002  162.080002
# 2017-09-06  162.710007  162.990005  160.520004  161.910004  161.910004
# 2017-09-07  162.089996  162.240005  160.360001  161.259995  161.259995
# 2017-09-08  160.860001  161.149994  158.529999  158.630005  158.630005
# 2017-09-11  160.500000  162.050003  159.889999  161.500000  161.500000
# 2017-09-12  162.610001  163.960007  158.770004  160.860001  160.860001
# 2017-09-13  159.869995  159.960007  157.910004  159.649994  159.649994
# 2017-09-14  158.990005  159.399994  158.089996  158.279999  158.279999
# 2017-09-15  158.470001  160.970001  158.000000  159.880005  159.880005
# 2017-09-18  160.110001  160.500000  158.000000  158.669998  158.669998
# 2017-09-19  159.509995  159.770004  158.440002  158.729996  158.729996
# 2017-09-20  157.899994  158.259995  153.830002  156.070007  156.070007
# 2017-09-21  155.800003  155.800003  152.750000  153.389999  153.389999
# 2017-09-22  151.539993  152.270004  150.559998  151.889999  151.889999
# 2017-09-25  149.990005  151.830002  149.160004  150.550003  150.550003
# 2017-09-26  151.779999  153.919998  151.690002  153.139999  153.139999
#
#               Volume
# Date
# 2017-08-31  26785100
# 2017-09-01  16591100
# 2017-09-05  29468500
# 2017-09-06  21651700
# 2017-09-07  21928500
# 2017-09-08  28611500
# 2017-09-11  31580800
# 2017-09-12  71714000
# 2017-09-13  44907400
# 2017-09-14  23760700
# 2017-09-15  49114600
# 2017-09-18  28269400
# 2017-09-19  20810600
# 2017-09-20  52951400
# 2017-09-21  37511700
# 2017-09-22  46645400
# 2017-09-25  44387300
# 2017-09-26  35764600

# %%
pandas_datareader.get_data_yahoo_actions("AAPL")
# Out:
#               value    action
# Date
# 2017-08-10  0.63000  DIVIDEND
# 2017-05-11  0.63000  DIVIDEND
# 2017-02-09  0.57000  DIVIDEND
# 2016-11-03  0.57000  DIVIDEND
# 2016-08-04  0.57000  DIVIDEND
# 2016-05-05  0.57000  DIVIDEND
# 2016-02-04  0.52000  DIVIDEND
# 2015-11-05  0.52000  DIVIDEND
# 2015-08-06  0.52000  DIVIDEND
# 2015-05-07  0.52000  DIVIDEND
# 2015-02-05  0.47000  DIVIDEND
# 2014-11-06  0.47000  DIVIDEND
# 2014-08-07  0.47000  DIVIDEND
# 2014-06-09  0.00000     SPLIT
# 2014-05-08  0.47000  DIVIDEND
# 2014-02-06  0.43571  DIVIDEND
# 2013-11-06  0.43571  DIVIDEND
# 2013-08-08  0.43571  DIVIDEND
# 2013-05-09  0.43571  DIVIDEND
# 2013-02-07  0.37857  DIVIDEND
# 2012-11-07  0.37857  DIVIDEND
# 2012-08-09  0.37857  DIVIDEND

# %% [markdown]
# # Financial Data Calculations and Statistics
#
# ### Single Symbol
#
# - Returns (Daily / Total / Yearly / Annualized )
# - Volatility (Daily / Annualized )
# - Sharpe Ratio
#
# - Alpha / Beta ( vs benchmark - e.g ^GSPC(S&P500))
#
# - Moving Average
#
#
# ### Multiple Symbols
#
# - Correlation
# - Covariance

# %% [markdown]
# # Financial Models
#
# ### Monte Carlo Simulation
#
#
# ### Black-Scholes Option Pricing
#
#
# ### Time-Series Model

# %% [markdown]
# # Simple Portoflio Processing
#
# - equal weights
# - stock and bonds (7 : 3)
# - periodically rebalance

# %% [markdown]
# # Online Trading Strategy
#
# ## Quantopian
#
# https://www.quantopian.com/posts/search?page=3&q=etf
#
# ## Github
#
# https://github.com/search?utf8=✓&q=etf+trading&type=
